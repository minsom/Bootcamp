# %% [markdown]
# # WeatherPy
# ----
#
# ### Analysis
# This sample data lacks cities located between latitude of -90 to -50.
# * The weather becomes warmer as one approaches the equator. But the max temperatures of northern and southern hemispheres seem to be similar in respect to their latitudes.
# * There is a cluster of cities with 100% humidity at latitudes of -20 to 0.
# * There is no apprent relationship between latitude and cloudiness but many cities have 0 cloudiness.
# * Wind speeds seem to increase from the equator.
#
# ---
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from pprint import pprint

# Import API key
from api_keys import api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
cities_df=pd.DataFrame(cities, columns=['City'])
cities_df.head()
# Out:
#           City
# 0     cherskiy
# 1  yellowknife
# 2   bredasdorp
# 3       hobart
# 4      pangody

# %%
cities_df['Country']=""
cities_df['Lat']=""
cities_df['Lng']=""
cities_df['Date']=""
cities_df['Cloudiness']=""
cities_df['Humidity']=""
cities_df['Max Temp']=""
cities_df['Wind Speed']=""

cities_df.head()
# Out:
#           City Country Lat Lng Date Cloudiness Humidity Max Temp Wind Speed
# 0     cherskiy
# 1  yellowknife
# 2   bredasdorp
# 3       hobart
# 4      pangody

# %% [markdown]
# # Perform API Calls¶
# Perform a weather check on each city using a series of successive API calls.
# Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
weathers=[]

base_url="http://api.openweathermap.org/data/2.5/weather?"
units='imperial'

print('''Beginning Data Retrieval     
-----------------------------''')
Set_counter=1

for index, row in cities_df.iterrows():
    city=row['City']
    city_url=url + "appid=" + api_key + "&units=" + units + "&q=" + city
    response=requests.get(city_url).json()
    
    if (index % 50 == 0 and index>=50):
        Set_counter+=1
    
    try:
        print(f'Processing Record {index} of Set {Set_counter} | {city.title()}')

        cities_df.loc[index,'Country']=response['sys']['country']
        cities_df.loc[index,'Lat']=response['coord']['lat']
        cities_df.loc[index,'Lng']=response['coord']['lon']
        cities_df.loc[index,'Date']=response['dt']
        cities_df.loc[index,'Cloudiness']=response['clouds']['all']
        cities_df.loc[index,'Humidity']=response['main']['humidity']
        cities_df.loc[index,'Max Temp']=response['main']['temp_max']
        cities_df.loc[index,'Wind Speed']=response['wind']['speed']
    except (KeyError, IndexError):
        print("City not found. Skipping...")
        
print('''-----------------------------
Data Retrieval Complete      
-----------------------------''')
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 0 of Set 1 | Cherskiy
# Processing Record 1 of Set 1 | Yellowknife
# Processing Record 2 of Set 1 | Bredasdorp
# Processing Record 3 of Set 1 | Hobart
# Processing Record 4 of Set 1 | Pangody
# Processing Record 5 of Set 1 | Hermanus
# Processing Record 6 of Set 1 | Busselton
# Processing Record 7 of Set 1 | Saint-Leu
# Processing Record 8 of Set 1 | Lata
# Processing Record 9 of Set 1 | Rungata
# City not found. Skipping...
# Processing Record 10 of Set 1 | Avarua
# Processing Record 11 of Set 1 | Norman Wells
# Processing Record 12 of Set 1 | Luanda
# Processing Record 13 of Set 1 | Berlevag
# Processing Record 14 of Set 1 | Albany
# Processing Record 15 of Set 1 | Dobryatino
# Processing Record 16 of Set 1 | Mount Gambier
# Processing Record 17 of Set 1 | Benguela
# Processing Record 18 of Set 1 | Dubbo
# Processing Record 19 of Set 1 | Iqaluit
# Processing Record 20 of Set 1 | Guanare
# Processing Record 21 of Set 1 | Berdigestyakh
# Processing Record 22 of Set 1 | Port Alfred
# Processing Record 23 of Set 1 | Rikitea
# Processing Record 24 of Set 1 | Kodiak
# Processing Record 25 of Set 1 | Broome
# Processing Record 26 of Set 1 | Conakry
# Processing Record 27 of Set 1 | Punta Arenas
# Processing Record 28 of Set 1 | New Norfolk
# Processing Record 29 of Set 1 | Mont-De-Marsan
# Processing Record 30 of Set 1 | North Platte
# Processing Record 31 of Set 1 | Mogadishu
# Processing Record 32 of Set 1 | Saint-Philippe
# Processing Record 33 of Set 1 | Gomel
# City not found. Skipping...
# Processing Record 34 of Set 1 | Kapaa
# Processing Record 35 of Set 1 | Ancud
# Processing Record 36 of Set 1 | Mataura
# Processing Record 37 of Set 1 | Awjilah
# Processing Record 38 of Set 1 | Namibe
# Processing Record 39 of Set 1 | Lolua
# City not found. Skipping...
# Processing Record 40 of Set 1 | Vaini
# Processing Record 41 of Set 1 | Bolekhiv
# Processing Record 42 of Set 1 | Porto Novo
# Processing Record 43 of Set 1 | Timizart
# Processing Record 44 of Set 1 | Tual
# Processing Record 45 of Set 1 | Ushuaia
# Processing Record 46 of Set 1 | Pulandian
# Processing Record 47 of Set 1 | Tabuk
# Processing Record 48 of Set 1 | Half Moon Bay
# Processing Record 49 of Set 1 | Tubinskiy
# Processing Record 50 of Set 2 | Bell Ville
# Processing Record 51 of Set 2 | Vostok
# Processing Record 52 of Set 2 | Caravelas
# Processing Record 53 of Set 2 | Tiksi
# Processing Record 54 of Set 2 | Ilulissat
# Processing Record 55 of Set 2 | Bluff
# Processing Record 56 of Set 2 | Sitka
# Processing Record 57 of Set 2 | Waipawa
# Processing Record 58 of Set 2 | Lebu
# Processing Record 59 of Set 2 | Dikson
# Processing Record 60 of Set 2 | Grand Gaube
# Processing Record 61 of Set 2 | Saldanha
# Processing Record 62 of Set 2 | Jining
# Processing Record 63 of Set 2 | Fortuna
# Processing Record 64 of Set 2 | Souillac
# Processing Record 65 of Set 2 | Tokzar
# City not found. Skipping...
# Processing Record 66 of Set 2 | Attawapiskat
# City not found. Skipping...
# Processing Record 67 of Set 2 | Taolanaro
# City not found. Skipping...
# Processing Record 68 of Set 2 | Longyearbyen
# Processing Record 69 of Set 2 | Beringovskiy
# Processing Record 70 of Set 2 | Cape Town
# Processing Record 71 of Set 2 | Bethel
# Processing Record 72 of Set 2 | Laranjeiras Do Sul
# Processing Record 73 of Set 2 | Ruteng
# Processing Record 74 of Set 2 | Collie
# Processing Record 75 of Set 2 | Tubruq
# City not found. Skipping...
# Processing Record 76 of Set 2 | Komsomolskiy
# Processing Record 77 of Set 2 | Kruisfontein
# Processing Record 78 of Set 2 | Hilo
# Processing Record 79 of Set 2 | Puerto Ayora
# Processing Record 80 of Set 2 | Kahului
# Processing Record 81 of Set 2 | Isangel
# Processing Record 82 of Set 2 | Yumbing
# Processing Record 83 of Set 2 | Dingli
# Processing Record 84 of Set 2 | Susangerd
# Processing Record 85 of Set 2 | Do Gonbadan
# Processing Record 86 of Set 2 | Pisco
# Processing Record 87 of Set 2 | Nikolskoye
# Processing Record 88 of Set 2 | Carnarvon
# Processing Record 89 of Set 2 | Ribeira Grande
# Processing Record 90 of Set 2 | Jamestown
# Processing Record 91 of Set 2 | Chokurdakh
# Processing Record 92 of Set 2 | Tautira
# Processing Record 93 of Set 2 | Bengkulu
# City not found. Skipping...
# Processing Record 94 of Set 2 | Guerrero Negro
# Processing Record 95 of Set 2 | Urumqi
# City not found. Skipping...
# Processing Record 96 of Set 2 | Srednekolymsk
# Processing Record 97 of Set 2 | Mar Del Plata
# Processing Record 98 of Set 2 | Barentsburg
# City not found. Skipping...
# Processing Record 99 of Set 2 | Onega
# Processing Record 100 of Set 3 | Tilichiki
# Processing Record 101 of Set 3 | Yokadouma
# Processing Record 102 of Set 3 | Luderitz
# Processing Record 103 of Set 3 | Clyde River
# Processing Record 104 of Set 3 | Victoria
# Processing Record 105 of Set 3 | Handwara
# City not found. Skipping...
# Processing Record 106 of Set 3 | Grand River South East
# City not found. Skipping...
# Processing Record 107 of Set 3 | Jalor
# Processing Record 108 of Set 3 | Khatanga
# Processing Record 109 of Set 3 | Pekan
# Processing Record 110 of Set 3 | Port Elizabeth
# Processing Record 111 of Set 3 | Alofi
# Processing Record 112 of Set 3 | Atuona
# Processing Record 113 of Set 3 | Kolno
# Processing Record 114 of Set 3 | Cabo San Lucas
# Processing Record 115 of Set 3 | Esperance
# Processing Record 116 of Set 3 | Mahebourg
# Processing Record 117 of Set 3 | San Patricio
# Processing Record 118 of Set 3 | Tasiilaq
# Processing Record 119 of Set 3 | Cumaribo
# City not found. Skipping...
# Processing Record 120 of Set 3 | Zhitikara
# City not found. Skipping...
# Processing Record 121 of Set 3 | Tagusao
# Processing Record 122 of Set 3 | Santiago De Chuco
# Processing Record 123 of Set 3 | Provideniya
# Processing Record 124 of Set 3 | Kirakira
# Processing Record 125 of Set 3 | Pevek
# Processing Record 126 of Set 3 | Vung Tau
# Processing Record 127 of Set 3 | Cap Malheureux
# Processing Record 128 of Set 3 | Aklavik
# Processing Record 129 of Set 3 | Severo-Kurilsk
# Processing Record 130 of Set 3 | Arraial Do Cabo
# Processing Record 131 of Set 3 | Gusau
# Processing Record 132 of Set 3 | Saskylakh
# Processing Record 133 of Set 3 | Amuntai
# Processing Record 134 of Set 3 | Raudeberg
# Processing Record 135 of Set 3 | Cabra
# Processing Record 136 of Set 3 | Tura
# Processing Record 137 of Set 3 | Abong Mbang
# Processing Record 138 of Set 3 | Ojinaga
# Processing Record 139 of Set 3 | Santa Cruz De Tenerife
# Processing Record 140 of Set 3 | Roma
# Processing Record 141 of Set 3 | Amderma
# City not found. Skipping...
# Processing Record 142 of Set 3 | Borovoy
# Processing Record 143 of Set 3 | Sergeyevka
# Processing Record 144 of Set 3 | Laguna
# Processing Record 145 of Set 3 | Chiniot
# Processing Record 146 of Set 3 | Palabuhanratu
# City not found. Skipping...
# Processing Record 147 of Set 3 | Uray
# Processing Record 148 of Set 3 | Lompoc
# Processing Record 149 of Set 3 | Tigzirt
# Processing Record 150 of Set 4 | Mandalgovi
# Processing Record 151 of Set 4 | Kaitangata
# Processing Record 152 of Set 4 | Bay-Khaak
# Processing Record 153 of Set 4 | Hithadhoo
# Processing Record 154 of Set 4 | San Andres
# Processing Record 155 of Set 4 | Tuktoyaktuk
# Processing Record 156 of Set 4 | Rio Gallegos
# Processing Record 157 of Set 4 | Tsihombe
# City not found. Skipping...
# Processing Record 158 of Set 4 | Stralsund
# Processing Record 159 of Set 4 | Tasbuget
# City not found. Skipping...
# Processing Record 160 of Set 4 | Biltine
# Processing Record 161 of Set 4 | Bambous Virieux
# Processing Record 162 of Set 4 | Hofn
# Processing Record 163 of Set 4 | Khowst
# City not found. Skipping...
# Processing Record 164 of Set 4 | Faanui
# Processing Record 165 of Set 4 | Nanortalik
# Processing Record 166 of Set 4 | Rio Grande
# Processing Record 167 of Set 4 | Ahuimanu
# Processing Record 168 of Set 4 | Thompson
# Processing Record 169 of Set 4 | Chuy
# Processing Record 170 of Set 4 | Preobrazheniye
# Processing Record 171 of Set 4 | Ahipara
# Processing Record 172 of Set 4 | Parras
# City not found. Skipping...
# Processing Record 173 of Set 4 | Bilma
# Processing Record 174 of Set 4 | Abu Kamal
# Processing Record 175 of Set 4 | Tuatapere
# Processing Record 176 of Set 4 | Sisimiut
# Processing Record 177 of Set 4 | Mys Shmidta
# City not found. Skipping...
# Processing Record 178 of Set 4 | Sibu
# Processing Record 179 of Set 4 | Barrow
# Processing Record 180 of Set 4 | Asayita
# City not found. Skipping...
# Processing Record 181 of Set 4 | Butaritari
# Processing Record 182 of Set 4 | Makakilo City
# Processing Record 183 of Set 4 | Payakumbuh
# Processing Record 184 of Set 4 | Santiago Del Estero
# Processing Record 185 of Set 4 | Turukhansk
# Processing Record 186 of Set 4 | Saleaula
# City not found. Skipping...
# Processing Record 187 of Set 4 | Upernavik
# Processing Record 188 of Set 4 | Samarai
# Processing Record 189 of Set 4 | Sao Joao Da Barra
# Processing Record 190 of Set 4 | Hobyo
# Processing Record 191 of Set 4 | Kungalv
# Processing Record 192 of Set 4 | Cache Creek
# Processing Record 193 of Set 4 | Eldorado
# Processing Record 194 of Set 4 | Pipri
# Processing Record 195 of Set 4 | Qaanaaq
# Processing Record 196 of Set 4 | Lorengau
# Processing Record 197 of Set 4 | Huarmey
# Processing Record 198 of Set 4 | Sola
# Processing Record 199 of Set 4 | Flin Flon
# Processing Record 200 of Set 5 | Georgetown
# Processing Record 201 of Set 5 | Luchegorsk
# Processing Record 202 of Set 5 | Hibbing
# Processing Record 203 of Set 5 | Sao Filipe
# Processing Record 204 of Set 5 | Vila Velha
# Processing Record 205 of Set 5 | Kununurra
# Processing Record 206 of Set 5 | Kashi
# City not found. Skipping...
# Processing Record 207 of Set 5 | Santa Rosalia
# Processing Record 208 of Set 5 | Mjolby
# Processing Record 209 of Set 5 | Richards Bay
# Processing Record 210 of Set 5 | Moose Factory
# Processing Record 211 of Set 5 | Lichuan
# Processing Record 212 of Set 5 | Guarapari
# Processing Record 213 of Set 5 | Dzhusaly
# City not found. Skipping...
# Processing Record 214 of Set 5 | Pacific Grove
# Processing Record 215 of Set 5 | Port Blair
# Processing Record 216 of Set 5 | Yarada
# Processing Record 217 of Set 5 | Mokrousovo
# Processing Record 218 of Set 5 | Babanusah
# City not found. Skipping...
# Processing Record 219 of Set 5 | Illoqqortoormiut
# City not found. Skipping...
# Processing Record 220 of Set 5 | Umm Lajj
# Processing Record 221 of Set 5 | Inhambane
# Processing Record 222 of Set 5 | Faya
# Processing Record 223 of Set 5 | Castro
# Processing Record 224 of Set 5 | Dolgoye
# Processing Record 225 of Set 5 | Narsaq
# Processing Record 226 of Set 5 | Coquimbo
# Processing Record 227 of Set 5 | Pingshan
# Processing Record 228 of Set 5 | Hasaki
# Processing Record 229 of Set 5 | Karamea
# City not found. Skipping...
# Processing Record 230 of Set 5 | Jiazi
# Processing Record 231 of Set 5 | Palotina
# Processing Record 232 of Set 5 | Vanderhoof
# Processing Record 233 of Set 5 | Teacapan
# Processing Record 234 of Set 5 | Nizhneyansk
# City not found. Skipping...
# Processing Record 235 of Set 5 | Guozhen
# Processing Record 236 of Set 5 | Lapua
# Processing Record 237 of Set 5 | Manokwari
# Processing Record 238 of Set 5 | Sandnessjoen
# Processing Record 239 of Set 5 | Kyzyl-Mazhalyk
# Processing Record 240 of Set 5 | Chuguyevka
# Processing Record 241 of Set 5 | Airai
# Processing Record 242 of Set 5 | Fereydunshahr
# Processing Record 243 of Set 5 | Skrunda
# Processing Record 244 of Set 5 | Atambua
# Processing Record 245 of Set 5 | Haines Junction
# Processing Record 246 of Set 5 | Torbay
# Processing Record 247 of Set 5 | Manaus
# Processing Record 248 of Set 5 | Phalodi
# Processing Record 249 of Set 5 | Lasa
# Processing Record 250 of Set 6 | Batemans Bay
# Processing Record 251 of Set 6 | Yinchuan
# Processing Record 252 of Set 6 | Fuyu
# Processing Record 253 of Set 6 | Tabiauea
# City not found. Skipping...
# Processing Record 254 of Set 6 | Anahuac
# Processing Record 255 of Set 6 | Paptalaya
# Processing Record 256 of Set 6 | Yerbogachen
# Processing Record 257 of Set 6 | Acari
# Processing Record 258 of Set 6 | Vao
# Processing Record 259 of Set 6 | Sentyabrskiy
# City not found. Skipping...
# Processing Record 260 of Set 6 | Chake Chake
# Processing Record 261 of Set 6 | Port Hardy
# Processing Record 262 of Set 6 | Braco Do Norte
# Processing Record 263 of Set 6 | Umea
# Processing Record 264 of Set 6 | Margate
# Processing Record 265 of Set 6 | Taclobo
# Processing Record 266 of Set 6 | Te Anau
# Processing Record 267 of Set 6 | Amboasary
# Processing Record 268 of Set 6 | Camana
# City not found. Skipping...
# Processing Record 269 of Set 6 | Babati
# Processing Record 270 of Set 6 | Ust-Tsilma
# Processing Record 271 of Set 6 | Teguise
# Processing Record 272 of Set 6 | Vaitupu
# City not found. Skipping...
# Processing Record 273 of Set 6 | Port Hedland
# Processing Record 274 of Set 6 | East London
# Processing Record 275 of Set 6 | Mahanoro
# Processing Record 276 of Set 6 | Santa Cruz
# Processing Record 277 of Set 6 | Bairiki
# City not found. Skipping...
# Processing Record 278 of Set 6 | Duku
# Processing Record 279 of Set 6 | Los Llanos De Aridane
# Processing Record 280 of Set 6 | Olinda
# Processing Record 281 of Set 6 | Dolores
# Processing Record 282 of Set 6 | Brigantine
# Processing Record 283 of Set 6 | Belaya Gora
# Processing Record 284 of Set 6 | Chernyshevskiy
# Processing Record 285 of Set 6 | Kosa
# Processing Record 286 of Set 6 | Wahran
# City not found. Skipping...
# Processing Record 287 of Set 6 | Itoman
# Processing Record 288 of Set 6 | Lahaina
# Processing Record 289 of Set 6 | Itaituba
# Processing Record 290 of Set 6 | Hamilton
# Processing Record 291 of Set 6 | Saint-Augustin
# Processing Record 292 of Set 6 | Pueblo
# Processing Record 293 of Set 6 | Fare
# Processing Record 294 of Set 6 | Bilibino
# Processing Record 295 of Set 6 | Gravdal
# Processing Record 296 of Set 6 | Ouro Preto Do Oeste
# Processing Record 297 of Set 6 | Mazatlan
# Processing Record 298 of Set 6 | Aflu
# City not found. Skipping...
# Processing Record 299 of Set 6 | Thinadhoo
# Processing Record 300 of Set 7 | Cervo
# Processing Record 301 of Set 7 | Madang
# Processing Record 302 of Set 7 | Omsukchan
# Processing Record 303 of Set 7 | Kultuk
# Processing Record 304 of Set 7 | Mackay
# Processing Record 305 of Set 7 | Hambantota
# Processing Record 306 of Set 7 | Pojejena
# Processing Record 307 of Set 7 | Lima
# Processing Record 308 of Set 7 | Arlit
# Processing Record 309 of Set 7 | Conchagua
# Processing Record 310 of Set 7 | Yenagoa
# Processing Record 311 of Set 7 | Kainantu
# Processing Record 312 of Set 7 | Antalaha
# Processing Record 313 of Set 7 | Bobonong
# City not found. Skipping...
# Processing Record 314 of Set 7 | Tynda
# Processing Record 315 of Set 7 | Chibuto
# Processing Record 316 of Set 7 | Port Lincoln
# Processing Record 317 of Set 7 | Badvel
# Processing Record 318 of Set 7 | Qingquan
# Processing Record 319 of Set 7 | Cidreira
# Processing Record 320 of Set 7 | Roald
# Processing Record 321 of Set 7 | Zamora
# Processing Record 322 of Set 7 | Nuuk
# Processing Record 323 of Set 7 | Valle De Allende
# Processing Record 324 of Set 7 | Kudahuvadhoo
# Processing Record 325 of Set 7 | Pozo Colorado
# Processing Record 326 of Set 7 | Dixon
# Processing Record 327 of Set 7 | Hengshui
# Processing Record 328 of Set 7 | Harper
# Processing Record 329 of Set 7 | Champerico
# Processing Record 330 of Set 7 | Marystown
# Processing Record 331 of Set 7 | Balogo
# Processing Record 332 of Set 7 | Noumea
# Processing Record 333 of Set 7 | Alekseyevsk
# Processing Record 334 of Set 7 | Namatanai
# Processing Record 335 of Set 7 | Setermoen
# Processing Record 336 of Set 7 | Nalut
# Processing Record 337 of Set 7 | Jurmala
# Processing Record 338 of Set 7 | Vanimo
# Processing Record 339 of Set 7 | Saint Anthony
# Processing Record 340 of Set 7 | Port-Gentil
# Processing Record 341 of Set 7 | Ukiah
# Processing Record 342 of Set 7 | Nouadhibou
# Processing Record 343 of Set 7 | Constitucion
# Processing Record 344 of Set 7 | Kemijarvi
# City not found. Skipping...
# Processing Record 345 of Set 7 | Taoudenni
# Processing Record 346 of Set 7 | Tarudant
# City not found. Skipping...
# Processing Record 347 of Set 7 | Shubarkuduk
# Processing Record 348 of Set 7 | Nioro
# Processing Record 349 of Set 7 | Yeppoon
# Processing Record 350 of Set 8 | Carsamba
# Processing Record 351 of Set 8 | Salalah
# Processing Record 352 of Set 8 | Seminole
# Processing Record 353 of Set 8 | Karasjok
# Processing Record 354 of Set 8 | Marsa Matruh
# Processing Record 355 of Set 8 | Ponta Do Sol
# Processing Record 356 of Set 8 | Lithakia
# Processing Record 357 of Set 8 | Longhua
# Processing Record 358 of Set 8 | Atar
# Processing Record 359 of Set 8 | Baykit
# Processing Record 360 of Set 8 | Naze
# Processing Record 361 of Set 8 | Kenai
# Processing Record 362 of Set 8 | Aksay
# Processing Record 363 of Set 8 | Vardo
# Processing Record 364 of Set 8 | Agva
# City not found. Skipping...
# Processing Record 365 of Set 8 | Colac
# Processing Record 366 of Set 8 | Lewistown
# Processing Record 367 of Set 8 | Karkaralinsk
# City not found. Skipping...
# Processing Record 368 of Set 8 | Gat
# Processing Record 369 of Set 8 | Sinjai
# Processing Record 370 of Set 8 | Klaksvik
# Processing Record 371 of Set 8 | Kamenka
# Processing Record 372 of Set 8 | Nayoro
# Processing Record 373 of Set 8 | Tungor
# Processing Record 374 of Set 8 | Bathsheba
# Processing Record 375 of Set 8 | Lieksa
# Processing Record 376 of Set 8 | Kuhdasht
# Processing Record 377 of Set 8 | Najran
# Processing Record 378 of Set 8 | Severo-Yeniseyskiy
# Processing Record 379 of Set 8 | Burkhala
# City not found. Skipping...
# Processing Record 380 of Set 8 | Marcona
# City not found. Skipping...
# Processing Record 381 of Set 8 | Yulara
# Processing Record 382 of Set 8 | Jaffna
# Processing Record 383 of Set 8 | Piet Retief
# Processing Record 384 of Set 8 | Taitung
# Processing Record 385 of Set 8 | Sokoto
# Processing Record 386 of Set 8 | Cayenne
# Processing Record 387 of Set 8 | Coxim
# Processing Record 388 of Set 8 | Tawkar
# City not found. Skipping...
# Processing Record 389 of Set 8 | Malakal
# City not found. Skipping...
# Processing Record 390 of Set 8 | Nizhnyaya Tavda
# Processing Record 391 of Set 8 | Rancho Palos Verdes
# Processing Record 392 of Set 8 | Kendari
# Processing Record 393 of Set 8 | Thai Binh
# Processing Record 394 of Set 8 | Klyuchi
# Processing Record 395 of Set 8 | Ulundi
# Processing Record 396 of Set 8 | Shimoda
# Processing Record 397 of Set 8 | Ushibuka
# Processing Record 398 of Set 8 | Rawalpindi
# Processing Record 399 of Set 8 | Igra
# Processing Record 400 of Set 9 | Saint George
# Processing Record 401 of Set 9 | Dickinson
# Processing Record 402 of Set 9 | Birjand
# Processing Record 403 of Set 9 | Igarka
# Processing Record 404 of Set 9 | Umzimvubu
# City not found. Skipping...
# Processing Record 405 of Set 9 | Maceio
# Processing Record 406 of Set 9 | Serrinha
# Processing Record 407 of Set 9 | Nasirabad
# Processing Record 408 of Set 9 | Basoko
# Processing Record 409 of Set 9 | Ilihan
# Processing Record 410 of Set 9 | Brae
# Processing Record 411 of Set 9 | Eydhafushi
# Processing Record 412 of Set 9 | Tiznit
# Processing Record 413 of Set 9 | Saint-Pierre
# Processing Record 414 of Set 9 | Leningradskiy
# Processing Record 415 of Set 9 | Tateyama
# Processing Record 416 of Set 9 | New Castle
# Processing Record 417 of Set 9 | Sogdiondon
# City not found. Skipping...
# Processing Record 418 of Set 9 | Alugan
# Processing Record 419 of Set 9 | Bodaybo
# Processing Record 420 of Set 9 | Hereford
# Processing Record 421 of Set 9 | Artvin
# Processing Record 422 of Set 9 | Killam
# Processing Record 423 of Set 9 | Tulun
# Processing Record 424 of Set 9 | Oktyabrskoye
# Processing Record 425 of Set 9 | Copiapo
# Processing Record 426 of Set 9 | Sulurpeta
# City not found. Skipping...
# Processing Record 427 of Set 9 | Vurnary
# Processing Record 428 of Set 9 | Karamay
# City not found. Skipping...
# Processing Record 429 of Set 9 | Porto Velho
# Processing Record 430 of Set 9 | Northam
# Processing Record 431 of Set 9 | Maniitsoq
# Processing Record 432 of Set 9 | Bursol
# City not found. Skipping...
# Processing Record 433 of Set 9 | Lichinga
# Processing Record 434 of Set 9 | Velingrad
# Processing Record 435 of Set 9 | Samana
# Processing Record 436 of Set 9 | Basco
# Processing Record 437 of Set 9 | Ucluelet
# Processing Record 438 of Set 9 | Berezovyy
# Processing Record 439 of Set 9 | Kawana Waters
# City not found. Skipping...
# Processing Record 440 of Set 9 | Kiunga
# Processing Record 441 of Set 9 | Port Macquarie
# Processing Record 442 of Set 9 | Yar-Sale
# Processing Record 443 of Set 9 | Banjar
# Processing Record 444 of Set 9 | Katsuura
# Processing Record 445 of Set 9 | Daru
# Processing Record 446 of Set 9 | Miraflores
# Processing Record 447 of Set 9 | Kikwit
# Processing Record 448 of Set 9 | Acarau
# City not found. Skipping...
# Processing Record 449 of Set 9 | Zhezkazgan
# Processing Record 450 of Set 10 | Ondjiva
# Processing Record 451 of Set 10 | Cap-Aux-Meules
# Processing Record 452 of Set 10 | Galveston
# Processing Record 453 of Set 10 | Boz
# Processing Record 454 of Set 10 | Marsh Harbour
# Processing Record 455 of Set 10 | Hornepayne
# Processing Record 456 of Set 10 | Hanyang
# Processing Record 457 of Set 10 | Padang
# Processing Record 458 of Set 10 | Zamardi
# Processing Record 459 of Set 10 | Waingapu
# Processing Record 460 of Set 10 | Luhyny
# Processing Record 461 of Set 10 | Taree
# Processing Record 462 of Set 10 | Comodoro Rivadavia
# Processing Record 463 of Set 10 | Ponta Delgada
# Processing Record 464 of Set 10 | Karratha
# Processing Record 465 of Set 10 | Whitehorse
# Processing Record 466 of Set 10 | Louisbourg
# City not found. Skipping...
# Processing Record 467 of Set 10 | Kailasahar
# City not found. Skipping...
# Processing Record 468 of Set 10 | Guaratinga
# City not found. Skipping...
# Processing Record 469 of Set 10 | Beaune
# Processing Record 470 of Set 10 | Liverpool
# Processing Record 471 of Set 10 | Gamba
# Processing Record 472 of Set 10 | Buala
# Processing Record 473 of Set 10 | Muros
# Processing Record 474 of Set 10 | Qasigiannguit
# Processing Record 475 of Set 10 | Petauke
# Processing Record 476 of Set 10 | Honiara
# Processing Record 477 of Set 10 | Ostrovnoy
# Processing Record 478 of Set 10 | Mombetsu
# Processing Record 479 of Set 10 | Borskoye
# Processing Record 480 of Set 10 | Asilah
# City not found. Skipping...
# Processing Record 481 of Set 10 | Paraiso
# Processing Record 482 of Set 10 | Batagay-Alyta
# Processing Record 483 of Set 10 | Karlskrona
# Processing Record 484 of Set 10 | Aleppo
# Processing Record 485 of Set 10 | Bereda
# Processing Record 486 of Set 10 | La Ronge
# Processing Record 487 of Set 10 | Chulumani
# Processing Record 488 of Set 10 | Codrington
# Processing Record 489 of Set 10 | Beruni
# City not found. Skipping...
# Processing Record 490 of Set 10 | Palmer
# Processing Record 491 of Set 10 | Ngukurr
# City not found. Skipping...
# Processing Record 492 of Set 10 | Lakselv
# Processing Record 493 of Set 10 | Nizhniy Bestyakh
# Processing Record 494 of Set 10 | Karauzyak
# City not found. Skipping...
# Processing Record 495 of Set 10 | Amol
# Processing Record 496 of Set 10 | Bundaberg
# Processing Record 497 of Set 10 | San Jose
# Processing Record 498 of Set 10 | Koyilandi
# City not found. Skipping...
# Processing Record 499 of Set 10 | Moussoro
# Processing Record 500 of Set 11 | Nelson Bay
# Processing Record 501 of Set 11 | Uzhur-4
# City not found. Skipping...
# Processing Record 502 of Set 11 | Beloha
# Processing Record 503 of Set 11 | Zemetchino
# Processing Record 504 of Set 11 | Auki
# Processing Record 505 of Set 11 | Chenghai
# Processing Record 506 of Set 11 | Sabalgarh
# Processing Record 507 of Set 11 | Cairns
# Processing Record 508 of Set 11 | Male
# Processing Record 509 of Set 11 | Fort-Shevchenko
# Processing Record 510 of Set 11 | Lensk
# Processing Record 511 of Set 11 | Cangzhou
# Processing Record 512 of Set 11 | Taman
# Processing Record 513 of Set 11 | Lencois Paulista
# Processing Record 514 of Set 11 | Cortez
# Processing Record 515 of Set 11 | Tomigusuku
# Processing Record 516 of Set 11 | San Quintin
# Processing Record 517 of Set 11 | Pouembout
# Processing Record 518 of Set 11 | Mayumba
# Processing Record 519 of Set 11 | Buraydah
# Processing Record 520 of Set 11 | Jaora
# Processing Record 521 of Set 11 | Kajaani
# Processing Record 522 of Set 11 | Moses Lake
# Processing Record 523 of Set 11 | Solnechnyy
# Processing Record 524 of Set 11 | Phan Thiet
# Processing Record 525 of Set 11 | Vestmannaeyjar
# Processing Record 526 of Set 11 | Andenes
# City not found. Skipping...
# Processing Record 527 of Set 11 | Corning
# Processing Record 528 of Set 11 | Boa Vista
# Processing Record 529 of Set 11 | Mana
# Processing Record 530 of Set 11 | Isiro
# Processing Record 531 of Set 11 | Novikovo
# Processing Record 532 of Set 11 | Nabire
# Processing Record 533 of Set 11 | Manyana
# Processing Record 534 of Set 11 | Develi
# Processing Record 535 of Set 11 | Kavaratti
# Processing Record 536 of Set 11 | Ituni
# City not found. Skipping...
# Processing Record 537 of Set 11 | Rodrigues Alves
# Processing Record 538 of Set 11 | San Rafael
# Processing Record 539 of Set 11 | Peterhead
# Processing Record 540 of Set 11 | Shache
# Processing Record 541 of Set 11 | Solsvik
# City not found. Skipping...
# Processing Record 542 of Set 11 | Moree
# Processing Record 543 of Set 11 | Wasilla
# Processing Record 544 of Set 11 | Mount Isa
# Processing Record 545 of Set 11 | Belmonte
# Processing Record 546 of Set 11 | Srivardhan
# Processing Record 547 of Set 11 | Feijo
# Processing Record 548 of Set 11 | Anadyr
# Processing Record 549 of Set 11 | Cagayan De Tawi-Tawi
# City not found. Skipping...
# Processing Record 550 of Set 12 | Necochea
# Processing Record 551 of Set 12 | Aykhal
# Processing Record 552 of Set 12 | Bandarbeyla
# Processing Record 553 of Set 12 | Pemba
# Processing Record 554 of Set 12 | Taburao
# City not found. Skipping...
# Processing Record 555 of Set 12 | Tumannyy
# City not found. Skipping...
# Processing Record 556 of Set 12 | Alotau
# City not found. Skipping...
# Processing Record 557 of Set 12 | Peniche
# Processing Record 558 of Set 12 | Usinsk
# Processing Record 559 of Set 12 | Khandyga
# Processing Record 560 of Set 12 | High Level
# Processing Record 561 of Set 12 | Sao Jose Da Coroa Grande
# Processing Record 562 of Set 12 | Taltal
# Processing Record 563 of Set 12 | Xinzhi
# Processing Record 564 of Set 12 | Erenhot
# Processing Record 565 of Set 12 | Tidore
# City not found. Skipping...
# Processing Record 566 of Set 12 | Sorland
# Processing Record 567 of Set 12 | Linkou
# Processing Record 568 of Set 12 | Lagoa
# Processing Record 569 of Set 12 | Berbera
# City not found. Skipping...
# Processing Record 570 of Set 12 | Kachiry
# Processing Record 571 of Set 12 | Solovetskiy
# City not found. Skipping...
# Processing Record 572 of Set 12 | Gull Lake
# Processing Record 573 of Set 12 | San Cristobal
# Processing Record 574 of Set 12 | Talnakh
# Processing Record 575 of Set 12 | Ferme-Neuve
# Processing Record 576 of Set 12 | Katherine
# Processing Record 577 of Set 12 | Mutsamudu
# City not found. Skipping...
# Processing Record 578 of Set 12 | Chalmette
# Processing Record 579 of Set 12 | Jiroft
# City not found. Skipping...
# Processing Record 580 of Set 12 | Krasnogorskoye
# Processing Record 581 of Set 12 | Cheuskiny
# City not found. Skipping...
# Processing Record 582 of Set 12 | Crotone
# Processing Record 583 of Set 12 | Henties Bay
# Processing Record 584 of Set 12 | Kattivakkam
# Processing Record 585 of Set 12 | Mnogovershinnyy
# Processing Record 586 of Set 12 | Jiwani
# Processing Record 587 of Set 12 | Petit Goave
# Processing Record 588 of Set 12 | Vulcan
# Processing Record 589 of Set 12 | Karaul
# City not found. Skipping...
# Processing Record 590 of Set 12 | Lunsar
# Processing Record 591 of Set 12 | Sioux Lookout
# Processing Record 592 of Set 12 | Bambanglipuro
# Processing Record 593 of Set 12 | Ust-Koksa
# Processing Record 594 of Set 12 | Chiredzi
# Processing Record 595 of Set 12 | Samusu
# City not found. Skipping...
# Processing Record 596 of Set 12 | Ubon Ratchathani
# Processing Record 597 of Set 12 | Assomada
# Processing Record 598 of Set 12 | Tanout
# Processing Record 599 of Set 12 | Coahuayana
# Processing Record 600 of Set 13 | Jardim
# Processing Record 601 of Set 13 | Severodvinsk
# Processing Record 602 of Set 13 | Marawi
# Processing Record 603 of Set 13 | Nizhniy Kuranakh
# Processing Record 604 of Set 13 | Markova
# Processing Record 605 of Set 13 | Antofagasta
# Processing Record 606 of Set 13 | Moskovskoye
# Processing Record 607 of Set 13 | Umm Kaddadah
# Processing Record 608 of Set 13 | Puro
# Processing Record 609 of Set 13 | Moron
# Processing Record 610 of Set 13 | Placido De Castro
# Processing Record 611 of Set 13 | Sambava
# Processing Record 612 of Set 13 | Tadine
# Processing Record 613 of Set 13 | Belushya Guba
# City not found. Skipping...
# Processing Record 614 of Set 13 | Adamovka
# Processing Record 615 of Set 13 | Maloyaz
# City not found. Skipping...
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# convert strings to float and drop missing values
cities_clean=cities_df.replace('', np.nan, inplace=False)
cities_clean=cities_clean.dropna(how='any')

cities_clean[['Cloudiness','Date','Humidity','Lat','Lng','Max Temp','Wind Speed']].astype(float)

cities_clean.dtypes
# Out:
# City           object
# Country        object
# Lat           float64
# Lng           float64
# Date          float64
# Cloudiness    float64
# Humidity      float64
# Max Temp      float64
# Wind Speed    float64
# dtype: object

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
# Output File (CSV)
cities_clean.to_csv("cities.csv", index=False)

# %%
cities_clean.head()
# Out:
#           City Country    Lat     Lng          Date  Cloudiness  Humidity  \
# 0     cherskiy      RU  68.75  161.30  1.553756e+09        32.0      58.0
# 1  yellowknife      CA  62.45 -114.38  1.553756e+09        90.0      92.0
# 2   bredasdorp      ZA -34.53   20.04  1.553756e+09        36.0      77.0
# 3       hobart      AU -42.88  147.33  1.553756e+09         0.0      40.0
# 4      pangody      RU  65.85   74.49  1.553756e+09        12.0      93.0
#
#    Max Temp  Wind Speed
# 0      2.15        6.51
# 1     21.99        9.17
# 2     66.20        8.05
# 3     73.00       12.75
# 4     24.74        9.31

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
cities_clean.plot.scatter(x="Lat", y="Max Temp",
                          title="Cities Latitude vs Max Temperature (03/27/19)",
                          color="skyblue", edgecolor="Black",
                          grid=True)
plt.xlim(-100,100)
# Save figure
plt.savefig("Latitude_vs_MaxTemp.png")

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %%
cities_clean.plot.scatter(x="Lat", y="Humidity",
                          title="Cities Latitude vs Humidity (03/27/19)",
                          color="skyblue", edgecolor="Black",
                          grid=True)
plt.xlim(-100,100)
# Save figure
plt.savefig("Latitude_vs_Humidity.png")

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %%
cities_clean.plot.scatter(x="Lat", y="Cloudiness",
                          title="Cities Latitude vs Cloudiness (03/27/19)",
                          color="skyblue", edgecolor="Black",
                          grid=True)
plt.xlim(-100,100)
# Save figure
plt.savefig("Latitude_vs_Cloudiness.png")

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
cities_clean.plot.scatter(x="Lat", y="Wind Speed",
                          title="Cities Latitude vs Wind Speed (03/27/19)",
                          color="skyblue", edgecolor="Black",
                          grid=True)
plt.xlim(-100,100)
# Save figure
plt.savefig("Latitude_vs_Wind_Speed.png")
